# %% [markdown]
# # 기본 코드

# %%
import cv2

face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')
eye_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_eye.xml')

img = cv2.imread('C:/Users/alswl/OneDrive/documents/2-2/ML2/ML_project/images-91.jpeg')

gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
faces = face_cascade.detectMultiScale(gray, 1.3,5)
for (x,y,w,h) in faces:
    cv2.rectangle(img, (x,y), (x+w, y+h), (255,0,0),2)
    roi_gray = gray[y:y+h, x:x+w]
    roi_color = img[y:y+h, x:x+w]
    eyes = eye_cascade.detectMultiScale(roi_gray)
    for (ex, ey, ew, eh) in eyes:
        cv2.rectangle(roi_color, (ex,ey), (ex+ew, ey+eh),(0,255,0),2)

cv2.imshow('Image view', img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# # 얼굴 crop - rectangle 제거

# %%
import cv2

face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')
eye_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_eye.xml')

img = cv2.imread('C:/Users/alswl/OneDrive/documents/2-2/ML2/ML_project/images-91.jpeg')

gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
faces = face_cascade.detectMultiScale(gray, 1.3,5)
for (x,y,w,h) in faces:
    '''
    a1 = y - int(h/10)
    a2 = y + h + int(h/10)
    a3 = x - int(w/10)
    a4 = x + w + int(w/10)

    cropped = img[a1:a2, a3:a4]
    '''
    cropped = img[y:y+h, x:x+w]
    cv2.imwrite('C:/Users/alswl/OneDrive/documents/2-2/ML2/ML_project/images-91_cropped.jpeg', cropped)

    '''
    cv2.rectangle(img, (x,y), (x+w, y+h), (255,0,0),2)
    roi_gray = gray[y:y+h, x:x+w]
    roi_color = img[y:y+h, x:x+w]
    eyes = eye_cascade.detectMultiScale(roi_gray)
    for (ex, ey, ew, eh) in eyes:
        cv2.rectangle(roi_color, (ex,ey), (ex+ew, ey+eh),(0,255,0),2)
    '''

cv2.imshow('Image view', cropped)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# # 눈 crop - rectangle 제거

# %%
import cv2

eye_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_eye.xml')

image_name = 'image-15'
img = cv2.imread('C:/Users/alswl/OneDrive/documents/2-2/ML2/ML_project/' + image_name + '.jpeg')
print('C:/Users/alswl/OneDrive/documents/2-2/ML2/ML_project/' + image_name + '.jpeg')

gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
eyes = eye_cascade.detectMultiScale(gray, 1.3,5)
img_num = 0
for (ex, ey, ew, eh) in eyes:

    # cv2.rectangle(img, (ex,ey), (ex+ew, ey+eh),(0,255,0),2)

    eye_cropped = img[ey:ey+eh, ex:ex+ew]
    cv2.imwrite('C:/Users/alswl/OneDrive/documents/2-2/ML2/ML_project/' + image_name + '-' + str(img_num) + '.jpeg', eye_cropped)

    img_num += 1


cv2.imshow('Image view', eye_cropped)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/MyDrive/2-2/ML2_project/data/collect(unlabeled_data)
# ---------------------------------------------------------------------------
# DisabledFunctionError                     Traceback (most recent call last)
# <ipython-input-3-2579e2720004> in <module>
#       7 image_num = 1
#       8 img = cv2.imread('./' +'unlabeled {}'.format(image_num) + '.jpeg')
# ----> 9 cv2.imshow(img)
#      10 '''
#      11 gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
#
# /usr/local/lib/python3.7/dist-packages/google/colab/_import_hooks/_cv2.py in wrapped(*args, **kwargs)
#      46   def wrapped(*args, **kwargs):
#      47     if not os.environ.get(env_var, False):
# ---> 48       raise DisabledFunctionError(message, name or func.__name__)
#      49     return func(*args, **kwargs)
#      50
#
# ...
